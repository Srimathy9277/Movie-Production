# %% [markdown]
# # MOVIE PRODUCTION

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### IMPORTING DATASET

# %%
production =pd.read_csv("C:\\Users\\91934\\OneDrive\\Desktop\\Production dataset.csv")

# %%
production
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# ### NATURE OF THE DATASET

# %%
print("Dataset contains", production.shape[0], "samples and" , production.shape[1], "features")
# Out:
# Dataset contains 4803 samples and 20 features

# %% [markdown]
# ### DATASET ATTRIBUTES

# %%
production.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %% [markdown]
# ### STATISTICAL OVERVIEW

# %%
production.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
production.tail()
# Out:
#       budget                                             genres  \
# 4798  220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# ...

# %%
production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
production.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %% [markdown]
# ### CHECKING NULL VALUES

# %%
production.isnull()
# Out:
#       budget  genres  homepage     id  keywords  original_language  \
# 0      False   False     False  False     False              False
# 1      False   False     False  False     False              False
# 2      False   False     False  False     False              False
# 3      False   False     False  False     False              False
# 4      False   False     False  False     False              False
# ...      ...     ...       ...    ...       ...                ...
# 4798   False   False      True  False     False              False
# 4799   False   False      True  False     False              False
# 4800   False   False     False  False     False              False
# 4801   False   False     False  False     False              False
# 4802   False   False      True  False     False              False
#
#       original_title  overview  popularity  production_companies  \
# 0              False     False       False                 False
# ...

# %%
production.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
production.fillna(0, inplace=True)

# %% [markdown]
# ### Displaying the titles and genres of the first 50 movies from the dataset.

# %%
num_rows, num_columns = production.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 4803
# Number of columns: 20

# %%
first_50 = production.head(50)
print(first_50[['title', 'genres']])
# Out:
#                                           title  \
# 0                                        Avatar
# 1      Pirates of the Caribbean: At World's End
# 2                                       Spectre
# 3                         The Dark Knight Rises
# 4                                   John Carter
# 5                                  Spider-Man 3
# 6                                       Tangled
# 7                       Avengers: Age of Ultron
# 8        Harry Potter and the Half-Blood Prince
# 9            Batman v Superman: Dawn of Justice
# 10                             Superman Returns
# 11                            Quantum of Solace
# 12   Pirates of the Caribbean: Dead Man's Chest
# 13                              The Lone Ranger
# 14                                 Man of Steel
# 15     The Chronicles of Narnia: Prince Caspian
# 16                                 The Avengers
# 17  Pirates of the Caribbean: On Stranger Tides
# ...

# %% [markdown]
# ### Displaying the movie categories that have a budget greater than $220,000.

# %%
budget_threshold = 220000
filtered_movies = production[production['budget'] > budget_threshold]

# %%
unique_genres = filtered_movies['genres'].unique()
print("Movie categories (genres) with a budget greater than $220,000: \\n")
print(unique_genres)
# Out:
# Movie categories (genres) with a budget greater than $220,000: \n
# ['[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'
#  '[{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]'
#  '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 80, "name": "Crime"}]'
#  ...
#  '[{"id": 878, "name": "Science Fiction"}, {"id": 10751, "name": "Family"}]'
#  '[{"id": 35, "name": "Comedy"}, {"id": 27, "name": "Horror"}, {"id": 53, "name": "Thriller"}]'
#  '[{"id": 10769, "name": "Foreign"}, {"id": 99, "name": "Documentary"}]']

# %% [markdown]
# ### Displaying the movie categories where the revenue is greater than $961,000,000.

# %%
revenue_threshold = 961000000
filtered_movies = production[production['revenue'] > revenue_threshold]

# %%
unique_genres = filtered_movies['genres'].unique()
print("Movie categories (genres) with revenue greater than $961,000,000: \\n")
print(unique_genres)
# Out:
# Movie categories (genres) with revenue greater than $961,000,000: \n
# ['[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'
#  '[{"id": 28, "name": "Action"}, {"id": 80, "name": "Crime"}, {"id": 18, "name": "Drama"}, {"id": 53, "name": "Thriller"}]'
#  '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 878, "name": "Science Fiction"}]'
#  '[{"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 28, "name": "Action"}]'
#  '[{"id": 878, "name": "Science Fiction"}, {"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}]'
#  '[{"id": 12, "name": "Adventure"}, {"id": 28, "name": "Action"}, {"id": 14, "name": "Fantasy"}]'
#  '[{"id": 18, "name": "Drama"}, {"id": 10749, "name": "Romance"}, {"id": 53, "name": "Thriller"}]'
#  '[{"id": 12, "name": "Adventure"}, {"id": 28, "name": "Action"}, {"id": 878, "name": "Science Fiction"}]'
# ...

# %% [markdown]
# ### Removeing the rows with value 0 from both the budget and revenue columns.

# %%
production = production.loc[(production['budget'] != 0) & (production['revenue'] != 0)]

production.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Listing the top 10 movies with the highest revenues and the top 10 movies with the least budget.

# %% [markdown]
# #### Top 10 Movies with the Highest Revenues:

# %%
top_10_revenue_movies = production.nlargest(10, 'revenue')
print("Top 10 movies with the highest revenues:")
print(top_10_revenue_movies[['title', 'revenue']])
# Out:
# Top 10 movies with the highest revenues:
#                           title     revenue
# 0                        Avatar  2787965087
# 25                      Titanic  1845034188
# 16                 The Avengers  1519557910
# 28               Jurassic World  1513528810
# 44                    Furious 7  1506249360
# 7       Avengers: Age of Ultron  1405403694
# 123                      Frozen  1274219009
# 31                   Iron Man 3  1215439994
# 525                     Minions  1156730962
# 26   Captain America: Civil War  1153304495

# %% [markdown]
# #### Top 10 Movies with the Least Budget:

# %%
top_10_budget_movies = production.nsmallest(10, 'budget')
print("\nTop 10 movies with the least budget:")
print(top_10_budget_movies[['title', 'budget']])
# Out:
# Top 10 movies with the least budget:
#                    title  budget
# 3078        Modern Times       1
# 2791  A Farewell to Arms       4
# 2652        Split Second       7
# 2671        Bran Nue Dae       7
# 3187        The Prophecy       8
# 2521   Of Horses and Men      10
# 2522           Nurse 3-D      10
# 2405            F.I.S.T.      11
# 1694      Angela's Ashes      25
# 1579      The 51st State      28

# %% [markdown]
# ### Clarifying how are popularities of movies related with the movie budgets:

# %%
correlation = production['popularity'].corr(production['budget'])

print(f"Correlation between Popularity and Budget: {correlation:.2f}")
# Out:
# Correlation between Popularity and Budget: 0.43

# %% [markdown]
# ### Ckecking whether are they correlated or totally uncorrelated with each other:

# %% [markdown]
# Interpretation of the correlation coefficient:
#
# If the correlation coefficient (often denoted as "r") is close to 1; it indicates a strong positive correlation, meaning that as movie budgets increase, popularity tends to increase as well.
#
# If the correlation coefficient is close to -1; it indicates a strong negative correlation, meaning that as movie budgets increase, popularity tends to decrease.
#
# If the correlation coefficient is close to 0; it suggests little to no linear correlation between the two variables, implying that movie budgets and popularity are not strongly related.

# %% [markdown]
# The value of the correlation coefficient will help you interpret the relationship. A positive value indicates a positive correlation, while a negative value suggests a negative correlation.

# %% [markdown]
# ### Identifying and displaying the names of all production companies along with the number of times they appear in the production.

# %%
production_company_counts = production['production_companies'].value_counts()

print(" \\n Production Companies and Their Counts: \\n")
print(production_company_counts)
# Out:
#  \n Production Companies and Their Counts: \n
# [{"name": "Paramount Pictures", "id": 4}]                                                                                                                                                             48
# []                                                                                                                                                                                                    41
# [{"name": "Universal Pictures", "id": 33}]                                                                                                                                                            35
# [{"name": "New Line Cinema", "id": 12}]                                                                                                                                                               29
# ...

# %% [markdown]
# ### Displaying the names of the top 25 production companies based on the number of movies they have produced in descending order of the number of movies produced.

# %%
production_company_counts = production['production_companies'].value_counts()

top_25_production_companies = production_company_counts.head(25)
print("Top 25 Production Companies based on the number of movies produced: //n")
print(top_25_production_companies)
# Out:
# Top 25 Production Companies based on the number of movies produced: //n
# [{"name": "Paramount Pictures", "id": 4}]                                                                           48
# []                                                                                                                  41
# [{"name": "Universal Pictures", "id": 33}]                                                                          35
# [{"name": "New Line Cinema", "id": 12}]                                                                             29
# [{"name": "Columbia Pictures", "id": 5}]                                                                            28
# [{"name": "Twentieth Century Fox Film Corporation", "id": 306}]                                                     25
# [{"name": "Warner Bros.", "id": 6194}]                                                                              24
# ...

# %% [markdown]
# ### Sorting the data in descending order based on revenue and filter the top 500 movies

# %%
sorted_production = production.sort_values(by='revenue', ascending=False)

top_500_movies = sorted_production.head(500)

# %%
top_500_movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# ...         ...                                                ...
# 390    85000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 1556   30000000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 669    70000000  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 687    60000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 684    65000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# ...

# %% [markdown]
# ### Calculating the measures of central tendency for the specified columns

# %%
mean_budget = top_500_movies['budget'].mean()
median_budget = top_500_movies['budget'].median()
mean_revenue = top_500_movies['revenue'].mean()
median_revenue = top_500_movies['revenue'].median()
mean_runtime = top_500_movies['runtime'].mean()
median_runtime = top_500_movies['runtime'].median()

# %%
print(f"Measures of Central Tendency (Top 500 Movies):")
print(f"Budget - Mean: {mean_budget:.2f}, Median: {median_budget:.2f}")
print(f"Revenue - Mean: {mean_revenue:.2f}, Median: {median_revenue:.2f}")
print(f"Runtime - Mean: {mean_runtime:.2f}, Median: {median_runtime:.2f}")
# Out:
# Measures of Central Tendency (Top 500 Movies):
# Budget - Mean: 103193736.00, Median: 95000000.00
# Revenue - Mean: 458577595.06, Median: 363001569.50
# Runtime - Mean: 118.72, Median: 116.00

# %% [markdown]
# ### Performing outlier analysis for the above three columns using box plots

# %% [markdown]
# #### Box Plot for Budget  of Top 500 Movies

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.boxplot(top_500_movies['budget'], vert=True)
plt.title('Budget Box Plot')
# Out:
# Text(0.5, 1.0, 'Budget Box Plot')

# %% [markdown]
# #### Box Plot for Revenue of Top 500 Movies

# %%
plt.subplot(1, 3, 2)
plt.boxplot(top_500_movies['revenue'], vert=True)
plt.title('Revenue Box Plot')
# Out:
# Text(0.5, 1.0, 'Revenue Box Plot')

# %% [markdown]
# ####  Box Plot for Runtime of Top 500 Movies

# %%
plt.subplot(1, 3, 3)
plt.boxplot(top_500_movies['runtime'], vert=True)
plt.title('Runtime Box Plot')
# Out:
# Text(0.5, 1.0, 'Runtime Box Plot')

# %% [markdown]
# ### Identifying and displaying the names of the movies along with their run times for those movies that have above average runtime

# %% [markdown]
# #### Calculating the average runtime for the top 500 movies:

# %%
average_runtime = top_500_movies['runtime'].mean()

# %% [markdown]
# #### Filtering the movies with runtimes above the average:

# %%
above_average_runtime_movies = top_500_movies[top_500_movies['runtime'] > average_runtime]

# %%
print("Movies with Above-Average Runtime:")
print(above_average_runtime_movies[['title', 'runtime']])
# Out:
# Movies with Above-Average Runtime:
#                  title  runtime
# 0               Avatar    162.0
# 25             Titanic    194.0
# 16        The Avengers    143.0
# 28      Jurassic World    124.0
# 44           Furious 7    137.0
# ...                ...      ...
# 502       The Terminal    128.0
# 390   It's Complicated    121.0
# 1556        Knocked Up    129.0
# 687       Jack Reacher    130.0
# 684         Collateral    120.0
#
# [234 rows x 2 columns]

# %% [markdown]
# ### Top 10 Movies by their Revenue

# %%
top_10_movies = production.sort_values(by='revenue', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.barh(top_10_movies['title'], top_10_movies['revenue'], color='skyblue')
plt.xlabel('Revenue')
plt.ylabel('Movie Title')
plt.title('Top 10 Movies by Revenue')
# Out:
# Text(0.5, 1.0, 'Top 10 Movies by Revenue')

# %% [markdown]
# ### Scatter Plot to compare the Revenue and Budget of Top 10 Movies

# %%
top_10_movies = production.sort_values(by='revenue', ascending=False).head(10)

plt.figure(figsize=(8, 6))
plt.scatter(top_10_movies['budget'], top_10_movies['revenue'], c='skyblue', alpha=0.7)
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.title('Top 10 Movies: Revenue vs. Budget')
plt.grid(True)

# %% [markdown]
# ### Box Plot of Revenue for Top 10 Movies

# %%
top_10_movies = production.sort_values(by='revenue', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.boxplot(top_10_movies['revenue'], vert=False)
plt.xlabel('Revenue')
plt.title('Box Plot of Revenue for Top 10 Movies')
plt.show()

# %% [markdown]
# ### Histogram of Revenue for Top 10 Movies

# %%
top_10_movies = production.sort_values(by='revenue', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.hist(top_10_movies['revenue'], bins=10, color='skyblue', alpha=0.7)
plt.xlabel('Revenue')
plt.ylabel('Frequency')
plt.title('Histogram of Revenue for Top 10 Movies')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Histogram for Top 10 Genres

# %%
genre_counts = production['genres'].value_counts().head(10)

plt.figure(figsize=(10, 6))
genre_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Genres')
plt.ylabel('Frequency')
plt.title('Top 10 Movie Genres')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Violin Plot of Revenue for Top 10 Movies

# %%
top_10_movies = production.sort_values(by='revenue', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.violinplot(x='revenue', data=top_10_movies, color='skyblue')
plt.xlabel('Revenue')
plt.title('Violin Plot of Revenue for Top 10 Movies')
plt.show()
